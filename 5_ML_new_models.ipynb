# %% [markdown]
# # After defined models test in doc 4, move to new models

# %% [markdown]
# ## Reference
# * (2017, May 23). Clinical Intervention Prediction and Understanding using Deep Networks. Retrieved December 3, 2018, from https://arxiv.org/abs/1705.08498
# * [NLP with Python](https://github.com/susanli2016/NLP-with-Python) reference
# * [Topic Modeling](https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24) reference

# %% [markdown]
# ## Before any prediction, let's see what topic modeling finds

# %% [markdown]
# Note: <b>Topic model</b> is a type of statistical model for discovering the abstract "topics" that occur in a collection of documents. Topic modeling is a frequently used text-mining tool for discovery of hidden semantic structures in a text body. Given that we have multiple clinicial notes (unstructured data) under each patient's history, we will practise what topic modeling brings us, before looking into more sophisticated machine learnings based on time series.

# %%
# import libraries
import pandas as pd
import numpy as np
np.random.seed(2018)

# topic modeling in python
import gensim              
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

# natural language toolkit
import nltk                
from nltk.stem import WordNetLemmatizer, SnowballStemmer
stemmer = SnowballStemmer('english')
from nltk.stem.porter import *
nltk.download('wordnet')

# TF-IDF
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ericx\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# test Lemmatize
[print(WordNetLemmatizer().lemmatize(item, pos='v')) 
    for item in ['went', 'goes', 'medicine', 'medicines', 'service', 'services']]
# Out:
# go
# go
# medicine
# medicine
# service
# service
# [None, None, None, None, None, None]

# %%
# define a function to perform lemmatize and stem preprocessing steps for the data set
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
# load data for a practise
# using 1000 lines of data from noteevents.csv table
noteevents = pd.read_csv('data/NOTEEVENTS.csv', nrows=1000)  
documents = noteevents[['SUBJECT_ID','TEXT']].sort_values(by=['SUBJECT_ID'], ascending=True)
print('type(documents): ', type(documents))
print('len(documents):', len(documents))
documents.head()
# Out:
# type(documents):  <class 'pandas.core.frame.DataFrame'>
# len(documents): 1000
#      SUBJECT_ID                                               TEXT
# 547          64  Admission Date:  [**2143-3-3**]       Discharg...
# 113         142  Admission Date:  [**2143-4-1**]     Discharge ...
# 824         151  Admission Date:  [**2145-5-6**]       Discharg...
# 921         170  Admission Date:  [**2189-9-4**]              D...
# 638         246  Admission Date:  [**2130-6-1**]              D...

# %%
doc_sample = documents[documents['SUBJECT_ID']==64].values[0][1]
print('original document:--------------')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n Tokenized and lemmatized documents:--------------- ')
print(preprocess(doc_sample))
# Out:
# original document:--------------
# ['Admission', 'Date:', '', '[**2143-3-3**]', '', '', '', '', '', '', 'Discharge', 'Date:', '', '[**2143-3-18**]\n\nDate', 'of', 'Birth:', '', '', '[**2116-6-27**]', '', '', '', '', '', '', 'Sex:', '', 'F\n\nService:', '', 'ACOVE\n\nCHIEF', 'COMPLAINT:', '', 'Fever.\n\nHISTORY', 'OF', 'PRESENT', 'ILLNESS:', '', 'The', 'patient', 'is', 'a', '26-year-old\nwoman', 'with', 'a', 'history', 'of', 'IV', 'drug', 'abuse,', 'who', 'initially\npresented', 'to', 'an', 'outside', 'hospital', 'on', '[**2143-3-2**]', 'from', 'a\ndrug', 'and', 'detoxification', 'facility', 'with', 'a', 'chief', 'complaint', 'of\nheadache,', 'abdominal', 'pain,', 'and', 'fever.', '', 'At', 'the', 'outside\nhospital,', 'the', 'patient', 'was', 'found', 'to', 'be', 'febrile', 'to', '104.6\ndegrees', 'F,', 'and', 'she', 'subsequently', 'developed', 'hypotension', 'with', 'a\nsystolic', 'blood', 'pressure', 'in', 'the', '80s.\n\nDuring', 'this', 'initial', 'evaluation,', 'the', 'patient', 'was', 'confused', 'and\nonly', 'intermittently', 'answering', 'questions.', '', 'There', 'was', 'concern\nfor', 'possible', 'headache,', 'neck', 'stiffness,', 'and', 'photophobia,', 'so\ngiven', 'the', 'concern', 'for', 'meningitis,', 'a', 'spinal', 'tap', 'was', 'done.\nThis', 'study', 'demonstrated', '50', 'white', 'blood', 'cells', '(84%\nneutrophils),', '10', 'red', 'blood', 'cells,', 'protein', 'of', '23,', 'glucose', 'of\n86,', 'and', '0-5', 'yeast', 'per', 'high', 'power', 'field.', '', 'Given', 'these', 'findings\nand', 'concern', 'for', 'meningitis,', 'the', 'patient', 'received', 'Vancomycin,\nceftriaxone,', 'metronidazole,', 'and', 'gentamicin', 'at', 'the', 'outside\nhospital.', '', 'Given', 'the', 'lack', 'of', 'Intensive', 'Care', 'Unit', 'beds', 'at', 'the\noutside', 'hospital,', 'the', 'patient', 'was', 'therefore', 'transferred', 'to\nthe', '[**Hospital1', '69**]', 'for', 'further\nevaluation.\n\nOn', 'arrival', 'to', 'the', 'Emergency', 'Department', 'at', 'the', '[**Hospital1', '346**],', 'the', 'patient', 'was', 'found', 'to', 'have\nicteric', 'sclerae,', 'a', '2/6', 'systolic', 'ejection', 'murmur,', 'abdominal\nguarding,', 'and', 'right', 'upper', 'quadrant', 'tenderness.', '', 'Given', 'the\nconcern', 'for', 'an', 'abdominal', 'process,', 'the', 'patient', 'was', 'given\nlevofloxacin', 'and', 'metronidazole;', 'she', 'was', 'also', 'given', 'Ambisome\ngiven', 'the', 'finding', 'of', 'yeast', 'in', 'her', 'CSF', 'at', 'the', 'outside\nhospital.\n\nIn', 'the', 'Emergency', 'Department,', 'she', 'had', 'an', 'abdominal', 'ultrasound\nthat', 'was', 'negative', 'for', 'the', 'presence', 'of', 'gallbladder', 'or', 'ductal\ndilatation.', '', 'Also', 'at', 'this', 'time,', 'the', 'patient', 'began', 'to', 'deny', 'the\nreport', 'that', 'she', 'was', 'HIV', 'positive;', 'this', 'report', 'has', 'been\nobtained', 'only', 'by', 'report', 'and', 'not', 'by', 'documented', 'laboratory\ntesting', 'from', 'the', 'outside', 'hospital.\n\nPAST', 'MEDICAL', 'HISTORY:\n1.', 'Intravenous', 'drug', 'abuse.\n2.', 'Cholelithiasis.\n3.', 'Cholecystectomy.\n4.', 'Spontaneous', 'abortion', 'x2.\n5.', 'Therapeutic', 'abortion', 'x1.\n\nALLERGIES:', '', 'No', 'known', 'drug', 'allergies.\n\nMEDICATIONS', 'ON', 'ADMISSION:', '', 'None.\n\nSOCIAL', 'HISTORY:', '', 'The', 'patient', 'is', 'a', 'single', 'mother', 'of', 'three\nchildren', 'ages', '9,', '8,', 'and', '2', 'years', 'old.', '', 'She', 'is', 'unemployed.', '', 'She\nlast', 'used', 'heroin', '3-4', 'days', 'prior', 'to', 'admission;', 'she', 'began', 'using\nheroin', 'one', 'year', 'prior', 'to', 'admission.', '', 'The', 'patient', 'smokes', 'a\nthird', 'of', 'a', 'pack', 'of', 'cigarettes', 'a', 'day', 'and', 'denies', 'any', 'history', 'of\nalcohol', 'abuse.', '', 'She', 'denies', 'any', 'history', 'of', 'providing', 'sexual\nfavors', 'for', 'drugs', 'or', 'money.', '', 'She', 'says', 'her', 'only', 'lifetime\npartner', 'is', 'her', 'husband.\n\nINITIAL', 'PHYSICAL', 'EXAMINATION:', '', 'Temperature', '97.6,', 'heart', 'rate\ ...
#
#
#  Tokenized and lemmatized documents:---------------
# ['admiss', 'date', 'discharg', 'date', 'date', 'birth', 'servic', 'acov', 'chief', 'complaint', 'fever', 'histori', 'present', 'ill', 'patient', 'year', 'woman', 'histori', 'drug', 'abus', 'initi', 'present', 'outsid', 'hospit', 'drug', 'detoxif', 'facil', 'chief', 'complaint', 'headach', 'abdomin', 'pain', 'fever', 'outsid', 'hospit', 'patient', 'febril', 'degre', 'subsequ', 'develop', 'hypotens', 'systol', 'blood', 'pressur', 'initi', 'evalu', 'patient', 'confus', 'intermitt', 'answer', 'question', 'concern', 'possibl', 'headach', 'neck', 'stiff', 'photophobia', 'give', 'concern', 'mening', 'spinal', 'studi', 'demonstr', 'white', 'blood', 'cell', 'neutrophil', 'blood', 'cell', 'protein', 'glucos', 'yeast', 'high', 'power', 'field', 'give', 'find', 'concern', 'mening', 'patient', 'receiv', 'vancomycin', 'ceftriaxon', 'metronidazol', 'gentamicin', 'outsid', 'hospit', 'give', 'lack', 'intens', 'care', 'unit', 'bed', 'outsid', 'hospit', 'patient', 'transfer', 'hospit', 'evalu', 'arriv', 'emerg', 'depart', 'hospit', 'patient', 'icter', 'sclera', 'systol', 'eject', 'murmur', 'abdomin', 'guard', 'right', 'upper', 'quadrant', 'tender', 'give', 'concern', 'abdomin', 'process', 'patient', 'give', 'levofloxacin', 'metronidazol', 'give', 'ambisom', 'give', 'find', 'yeast', 'outsid', 'hospit', 'emerg', 'depart', 'abdomin', 'ultrasound', 'negat', 'presenc', 'gallbladd', 'ductal', 'dilat', 'time', 'patient', 'begin', 'deni', 'report', 'posit', 'report', 'obtain', 'report', 'document', 'laboratori', 'test', 'outsid', 'hospit', 'past', 'medic', 'histori', 'intraven', 'drug', 'abus', 'cholelithiasi', 'cholecystectomi', 'spontan', 'abort', 'therapeut', 'abort', 'allergi', 'know', 'drug', 'allergi', 'medic', 'admiss', 'social', 'histori', 'patient', 'singl', 'mother', 'children', 'age', 'year', 'unemploy', 'heroin', 'day', 'prior', 'admiss', 'begin', 'heroin', 'year', 'prior', 'admiss', 'patient', 'smoke', 'pack', 'cigarett', 'deni', 'histori', 'alcohol', 'abus', 'deni', 'histori', 'provid', 'sexual', 'favor', 'drug', 'money', 'say', 'lifetim', 'partner', 'husband', 'initi', 'physic', 'examin', 'temperatur', 'heart', 'rate', 'blood', 'pressur', 'respiratori', 'rate', 'oxygen', 'satur', 'room', 'initi', 'evalu', 'patient', 'reliabl', 'historian', 'appear', 'dress', 'nourish', 'femal', 'moder', 'distress', 'feel', 'lie', 'subsequ', 'have', 'emesi', 'heent', 'exam', 'extraocular', 'movement', 'intact', 'mild', 'scleral', 'icterus', 'mild', 'conjunctiv', 'edema', 'pupil', 'equal', 'round', 'reactiv', 'light', 'small', 'conjunctiv', 'hemorrhag', 'right', 'greater', 'leav', 'face', 'symmetr', 'neck', 'stiff', 'pain', 'flexion', 'half', 'chest', 'right', 'central', 'venous', 'cathet', 'place', 'small', 'posterior', 'cervic', 'lymph', 'node', 'palpabl', 'oropharyng', 'examin', 'remark', 'upper', 'dentur', 'erod', 'mucosa', 'white', 'plaqu', 'consist', 'thrush', 'underneath', 'tongu', 'coat', 'whitish', 'film', 'petechia', 'upper', 'palat', 'heart', 'regular', 'rate', 'rhythm', 'holosystol', 'murmur', 'precordium', 'radiat', 'axilla', 'lung', 'clear', 'auscult', 'bilater', 'abdomen', 'soft', 'normoact', 'bowel', 'sound', 'bilater', 'upper', 'quadrant', 'guard', 'mild', 'abdomin', 'distent', 'patient', 'note', 'abdomin', 'discomfort', 'present', 'past', 'month', 'bilater', 'upper', 'extrem', 'tract', 'mark', 'right', 'forearm', 'bilater', 'antecubit', 'fossa', 'clean', 'scatter', 'dark', 'macul', 'see', 'palm', 'bilater', 'mild', 'true', 'pelvic', 'examin', 'move', 'extrem', 'freeli', 'equal', 'strength', 'neurolog', 'examin', 'laboratori', 'outsid', 'hospit', 'includ', 'follow', 'urinalysi', 'essenti', 'negat', 'blood', 'cultur', 'bottl', 'grow', 'gram', 'posit', 'cocci', 'cluster', 'initi', 'demonstr', 'neutrophil', 'yeast', 'high', 'power', 'field', 'blood', 'cell', 'white', 'cell', 'neutrophil', 'lymphocyt', 'monocyt', 'protein', 'glucos', 'complet', 'blood', 'count', 'show', 'white', 'count', 'hematocrit', 'platelet', 'differenti', 'white', 'count', ...

# %%
processed_docs = documents['TEXT'].map(preprocess)
processed_docs[:10]
# Out:
# 547    [admiss, date, discharg, date, date, birth, se...
# 113    [admiss, date, discharg, date, date, birth, se...
# 824    [admiss, date, discharg, date, servic, cardiot...
# 921    [admiss, date, discharg, date, date, birth, se...
# 638    [admiss, date, discharg, date, date, birth, se...
# 407    [admiss, date, discharg, date, date, birth, se...
# 742    [admiss, date, discharg, date, date, birth, se...
# 743    [admiss, date, discharg, date, date, birth, se...
# 805    [admiss, date, discharg, date, date, birth, se...
# 252    [admiss, date, discharg, date, servic, medicin...
# Name: TEXT, dtype: object

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
dictionary
# Out:
# ItemsView(<gensim.corpora.dictionary.Dictionary object at 0x00000219B55CD9E8>)

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 abdomen
# 1 abdomin
# 2 abnorm
# 3 abort
# 4 abscess
# 5 abus
# 6 acov
# 7 acut
# 8 addit
# 9 adequ
# 10 admiss

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[64]
# Out:
# [(3, 2),
#  (4, 4),
#  (10, 1),
#  (18, 5),
#  (29, 2),
#  (32, 1),
#  (40, 1),
#  (45, 1),
#  (50, 1),
#  (51, 2),
#  (54, 1),
#  (55, 4),
#  (57, 10),
#  (60, 1),
#  (61, 1),
#  (63, 1),
#  (77, 1),
#  (84, 2),
#  (85, 2),
#  (89, 1),
#  (90, 7),
#  (91, 1),
#  (92, 4),
#  (95, 1),
#  (99, 2),
#  (101, 3),
#  (102, 3),
#  (103, 1),
#  (104, 3),
#  (105, 2),
#  (112, 3),
#  (120, 6),
#  (122, 3),
#  (126, 3),
#  (129, 1),
#  (131, 1),
#  (134, 8),
#  (137, 1),
#  (141, 1),
#  (143, 1),
#  (144, 1),
#  (147, 1),
#  (159, 2),
#  (161, 3),
#  (163, 1),
#  (165, 1),
#  (168, 1),
#  (170, 1),
#  (175, 1),
#  (180, 2),
#  (187, 1),
#  (188, 2),
#  (192, 1),
#  (193, 6),
#  (194, 1),
#  (197, 3),
#  (201, 2),
#  (204, 2),
#  (206, 1),
#  (208, 2),
#  (211, 1),
#  (214, 1),
#  (215, 2),
#  (216, 1),
#  (221, 1),
#  (224, 2),
#  (228, 1),
#  (229, 1),
#  (231, 1),
#  (244, 1),
#  (245, 1),
#  (251, 5),
#  (258, 1),
#  (260, 7),
#  (261, 1),
#  (264, 2),
#  (267, 3),
#  (274, 2),
#  (277, 1),
#  (278, 8),
#  (281, 1),
#  (282, 1),
#  (283, 2),
#  (287, 1),
#  (292, 1),
#  (296, 1),
#  (299, 1),
#  (307, 4),
#  (309, 3),
#  (310, 1),
#  (311, 6),
#  (312, 1),
#  (314, 8),
#  (327, 1),
#  (329, 2),
#  (333, 1),
#  (335, 2),
#  (337, 2),
#  (338, 4),
#  (340, 1),
#  (342, 1),
#  (348, 1),
#  (354, 1),
#  (357, 1),
#  (359, 2),
#  (360, 1),
#  (363, 3),
#  (365, 1),
#  (368, 2),
#  (378, 3),
#  (379, 2),
#  (381, 2),
#  (386, 2),
#  (387, 1),
#  (391, 3),
#  (393, 3),
#  (397, 8),
#  (400, 1),
#  (402, 1),
#  (408, 1),
#  (410, 5),
#  (417, 1),
#  (420, 1),
#  (421, 1),
#  (424, 1),
#  (426, 1),
#  (427, 1),
#  (430, 1),
#  (431, 5),
#  (433, 1),
#  (438, 2),
#  (439, 1),
#  (440, 1),
#  (464, 1),
#  (466, 13),
#  (467, 1),
#  (469, 1),
#  (470, 1),
#  (472, 1),
#  (473, 1),
#  (475, 1),
#  (479, 1),
#  (480, 1),
#  (482, 1),
#  (491, 1),
#  (494, 1),
#  (495, 2),
#  (498, 11),
#  (500, 2),
#  (501, 1),
#  (503, 1),
#  (506, 1),
#  (507, 1),
#  (508, 1),
#  (509, 8),
#  (512, 2),
#  (514, 2),
#  (515, 1),
#  (517, 1),
#  (520, 1),
#  (521, 1),
#  (525, 1),
#  (530, 1),
#  (532, 1),
#  (538, 1),
#  (548, 2),
#  (550, 3),
#  (554, 1),
#  (555, 1),
#  (557, 1),
#  (558, 1),
#  (561, 1),
#  (568, 2),
#  (584, 2),
#  (589, 2),
#  (598, 1),
#  (600, 2),
#  (608, 2),
#  (616, 1),
#  (624, 6),
#  (625, 1),
#  (629, 1),
#  (635, 2),
#  (655, 1),
#  (657, 2),
#  (660, 1),
#  (661, 1),
#  (670, 1),
#  (671, 1),
#  (675, 5),
#  (689, 1),
#  (694, 3),
#  (696, 1),
#  (701, 1),
#  (704, 1),
#  (705, 2),
#  (709, 1),
#  (710, 2),
#  (727, 2),
#  (730, 1),
#  (742, 1),
#  (750, 3),
#  (752, 1),
#  (781, 2),
#  (790, 1),
#  (792, 1),
#  (803, 1),
#  (818, 1),
#  (838, 1),
#  (852, 3),
#  (859, 1),
#  (861, 1),
#  (875, 1),
#  (876, 1),
#  (882, 1),
#  (886, 1),
#  (887, 2),
#  (908, 1),
#  (916, 2),
#  (919, 1),
#  (923, 2),
#  (929, 1),
#  (940, 1),
#  (941, 1),
#  (952, 1),
#  (970, 1),
#  (971, 3),
#  (975, 1),
#  (977, 1),
#  (979, 2),
#  (985, 1),
#  (989, 1),
#  (1007, 3),
#  (1011, 1),
#  (1026, 2),
#  (1029, 1),
#  (1032, 1),
#  (1039, 1),
#  (1051, 1),
#  (1062, 3),
#  (1064, 10),
#  (1081, 1),
#  (1086, 2),
#  (1100, 2),
#  (1112, 1),
#  (1136, 1),
#  (1148, 1),
#  (1156, 1),
#  (1172, 1),
#  (1177, 1),
#  (1181, 1),
#  (1206, 1),
#  (1208, 2),
#  (1220, 3),
#  (1224, 4),
#  (1225, 3),
#  (1228, 1),
#  (1232, 2),
#  (1277, 1),
#  (1280, 2),
#  (1288, 5),
#  (1300, 3),
#  (1311, 3),
#  (1316, 2),
#  (1331, 1),
#  (1342, 1),
#  (1359, 1),
#  (1392, 1),
#  (1407, 3),
#  (1413, 2),
#  (1414, 2),
#  (1440, 1),
#  (1451, 1),
#  (1459, 1),
#  (1462, 3),
#  (1469, 1),
#  (1474, 1),
#  (1478, 4),
#  (1499, 1),
#  (1504, 1),
#  (1509, 1),
#  (1512, 1),
#  (1526, 2),
#  (1575, 1),
#  (1576, 1),
#  (1579, 1),
#  (1592, 1),
#  (1596, 1),
#  (1598, 1),
#  (1610, 1),
#  (1633, 1),
#  (1635, 1),
#  (1691, 1),
#  (1749, 1),
#  (1789, 1),
#  (1801, 2),
#  (1816, 1),
#  (1824, 1),
#  (1832, 1),
#  (1933, 1),
#  (1966, 1),
#  (1973, 1),
#  (2010, 1),
#  (2018, 4),
#  (2048, 1),
#  (2060, 2),
#  (2076, 1),
#  (2082, 1),
#  (2122, 1),
#  (2125, 1),
#  (2136, 1),
#  (2157, 5),
#  (2170, 1),
#  (2172, 1),
#  (2173, 1),
#  (2183, 1),
#  (2197, 2),
#  (2198, 2),
#  (2213, 2),
#  (2226, 4),
#  (2300, 1),
#  (2325, 1),
#  (2409, 1),
#  (2450, 1),
#  (2454, 4),
#  (2455, 3),
#  (2456, 2),
#  (2457, 1),
#  (2458, 1),
#  (2459, 1),
#  (2460, 1),
#  (2461, 1),
#  (2462, 1),
#  (2463, 1),
#  (2464, 1),
#  (2465, 1),
#  (2466, 1),
#  (2467, 1),
#  (2468, 1)]

# %%
bow_doc_64 = bow_corpus[64]

for i in range(len(bow_doc_64)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_64[i][0], 
                                                     dictionary[bow_doc_64[i][0]], 
                                                     bow_doc_64[i][1]))
# Out:
# Word 3 ("abus") appears 2 time.
# Word 4 ("addit") appears 4 time.
# Word 10 ("albumin") appears 1 time.
# Word 18 ("antibiot") appears 5 time.
# Word 29 ("atelectasi") appears 2 time.
# Word 32 ("atyp") appears 1 time.
# Word 40 ("band") appears 1 time.
# Word 45 ("bicarbon") appears 1 time.
# Word 50 ("calcium") appears 1 time.
# Word 51 ("call") appears 2 time.
# Word 54 ("cardiovascular") appears 1 time.
# Word 55 ("cathet") appears 4 time.
# Word 57 ("cell") appears 10 time.
# Word 60 ("check") appears 1 time.
# Word 61 ("chemistri") appears 1 time.
# Word 63 ("chlorid") appears 1 time.
# Word 77 ("complic") appears 1 time.
# Word 84 ("consist") appears 2 time.
# Word 85 ("consult") appears 2 time.
# Word 89 ("control") appears 1 time.
# Word 90 ("count") appears 7 time.
# Word 91 ("creatinin") appears 1 time.
# Word 92 ("cultur") appears 4 time.
# Word 95 ("decis") appears 1 time.
# Word 99 ("degre") appears 2 time.
# Word 101 ("depart") appears 3 time.
# Word 102 ("develop") appears 3 time.
# Word 103 ("diagnos") appears 1 time.
# Word 104 ("dictat") appears 3 time.
# Word 105 ("differenti") appears 2 time.
# Word 112 ("distress") appears 3 time.
# Word 120 ("effus") appears 6 time.
# Word 122 ("elev") appears 3 time.
# Word 126 ("emerg") appears 3 time.
# Word 129 ("enhanc") appears 1 time.
# Word 131 ("equal") appears 1 time.
# Word 134 ("examin") appears 8 time.
# Word 137 ("face") appears 1 time.
# Word 141 ("febril") appears 1 time.
# Word 143 ("felt") appears 1 time.
# Word 144 ("femal") appears 1 time.
# Word 147 ("film") appears 1 time.
# Word 159 ("good") appears 2 time.
# Word 161 ("gram") appears 3 time.
# Word 163 ("grow") appears 1 time.
# Word 165 ("half") appears 1 time.
# Word 168 ("head") appears 1 time.
# Word 170 ("hematocrit") appears 1 time.
# Word 175 ("high") appears 1 time.
# Word 180 ("hypotens") appears 2 time.
# Word 187 ("infect") appears 1 time.
# Word 188 ("infecti") appears 2 time.
# Word 192 ("intact") appears 1 time.
# Word 193 ("intens") appears 6 time.
# Word 194 ("intermitt") appears 1 time.
# Word 197 ("intraven") appears 3 time.
# Word 201 ("laboratori") appears 2 time.
# Word 204 ("later") appears 2 time.
# Word 206 ("lesion") appears 1 time.
# Word 208 ("levofloxacin") appears 2 time.
# Word 211 ("light") appears 1 time.
# Word 214 ("lymphocyt") appears 1 time.
# Word 215 ("magnesium") appears 2 time.
# Word 216 ("manag") appears 1 time.
# Word 221 ("medquist") appears 1 time.
# Word 224 ("metronidazol") appears 2 time.
# Word 228 ("moder") appears 1 time.
# Word 229 ("monocyt") appears 1 time.
# Word 231 ("mother") appears 1 time.
# Word 244 ("neurolog") appears 1 time.
# Word 245 ("neutrophil") appears 1 time.
# Word 251 ("obtain") appears 5 time.
# Word 258 ("overal") appears 1 time.
# Word 260 ("oxygen") appears 7 time.
# Word 261 ("pack") appears 1 time.
# Word 264 ("pantoprazol") appears 2 time.
# Word 267 ("pend") appears 3 time.
# Word 274 ("placement") appears 2 time.
# Word 277 ("platelet") appears 1 time.
# Word 278 ("pleural") appears 8 time.
# Word 281 ("possibl") appears 1 time.
# Word 282 ("posterior") appears 1 time.
# Word 283 ("potassium") appears 2 time.
# Word 287 ("process") appears 1 time.
# Word 292 ("pupil") appears 1 time.
# Word 296 ("reactiv") appears 1 time.
# Word 299 ("regimen") appears 1 time.
# Word 307 ("respiratori") appears 4 time.
# Word 309 ("return") appears 3 time.
# Word 310 ("rhythm") appears 1 time.
# Word 311 ("room") appears 6 time.
# Word 312 ("round") appears 1 time.
# Word 314 ("satur") appears 8 time.
# Word 327 ("sign") appears 1 time.
# Word 329 ("signific") appears 2 time.
# Word 333 ("size") appears 1 time.
# Word 335 ("small") appears 2 time.
# Word 337 ("smoke") appears 2 time.
# Word 338 ("sound") appears 4 time.
# Word 340 ("spike") appears 1 time.
# Word 342 ("spontan") appears 1 time.
# Word 348 ("strength") appears 1 time.
# Word 354 ("support") appears 1 time.
# Word 357 ("symptom") appears 1 time.
# Word 359 ("system") appears 2 time.
# Word 360 ("systol") appears 1 time.
# Word 363 ("temperatur") appears 3 time.
# Word 365 ("tender") appears 1 time.
# Word 368 ("therapi") appears 2 time.
# Word 378 ("treatment") appears 3 time.
# Word 379 ("trend") appears 2 time.
# Word 381 ("twice") appears 2 time.
# Word 386 ("upper") appears 2 time.
# Word 387 ("urinalysi") appears 1 time.
# Word 391 ("vancomycin") appears 3 time.
# Word 393 ("venous") appears 3 time.
# Word 397 ("white") appears 8 time.
# Word 400 ("activ") appears 1 time.
# Word 402 ("alert") appears 1 time.
# Word 408 ("anterior") appears 1 time.
# Word 410 ("assist") appears 5 time.
# Word 417 ("cardiothorac") appears 1 time.
# Word 420 ("club") appears 1 time.
# Word 421 ("colac") appears 1 time.
# Word 424 ("cranial") appears 1 time.
# Word 426 ("cyanosi") appears 1 time.
# Word 427 ("decid") appears 1 time.
# Word 430 ("dorsali") appears 1 time.
# Word 431 ("drain") appears 5 time.
# Word 433 ("ear") appears 1 time.
# Word 438 ("extub") appears 2 time.
# Word 439 ("eye") appears 1 time.
# Word 440 ("father") appears 1 time.
# Word 464 ("lymphadenopathi") appears 1 time.
# Word 466 ("mouth") appears 13 time.
# Word 467 ("nerv") appears 1 time.
# Word 469 ("nitrogen") appears 1 time.
# Word 470 ("nondistend") appears 1 time.
# Word 472 ("nontend") appears 1 time.
# Word 473 ("nose") appears 1 time.
# Word 475 ("occasion") appears 1 time.
# Word 479 ("orient") appears 1 time.
# Word 480 ("pedi") appears 1 time.
# Word 482 ("period") appears 1 time.
# Word 491 ("radiolog") appears 1 time.
# Word 494 ("rehabilit") appears 1 time.
# Word 495 ("remov") appears 2 time.
# Word 498 ("reveal") appears 11 time.
# Word 500 ("second") appears 2 time.
# Word 501 ("skin") appears 1 time.
# Word 503 ("state") appears 1 time.
# Word 506 ("success") appears 1 time.
# Word 507 ("summari") appears 1 time.
# Word 508 ("suppl") appears 1 time.
# Word 509 ("surgeri") appears 8 time.
# Word 512 ("throat") appears 2 time.
# Word 514 ("tobacco") appears 2 time.
# Word 515 ("toler") appears 1 time.
# Word 517 ("undergo") appears 1 time.
# Word 520 ("urea") appears 1 time.
# Word 521 ("valu") appears 1 time.
# Word 525 ("vital") appears 1 time.
# Word 530 ("advis") appears 1 time.
# Word 532 ("approxim") appears 1 time.
# Word 538 ("breast") appears 1 time.
# Word 548 ("daughter") appears 2 time.
# Word 550 ("depress") appears 3 time.
# Word 554 ("diet") appears 1 time.
# Word 555 ("docus") appears 1 time.
# Word 557 ("drive") appears 1 time.
# Word 558 ("drop") appears 1 time.
# Word 561 ("eventu") appears 1 time.
# Word 568 ("heparin") appears 2 time.
# Word 584 ("maintain") appears 2 time.
# Word 589 ("multivitamin") appears 2 time.
# Word 598 ("pattern") appears 1 time.
# Word 600 ("physician") appears 2 time.
# Word 608 ("recoveri") appears 2 time.
# Word 616 ("sinemet") appears 1 time.
# Word 624 ("tube") appears 6 time.
# Word 625 ("tylenol") appears 1 time.
# Word 629 ("vessel") appears 1 time.
# Word 635 ("work") appears 2 time.
# Word 655 ("comfort") appears 1 time.
# Word 657 ("cough") appears 2 time.
# Word 660 ("difficulti") appears 1 time.
# Word 661 ("dizzi") appears 1 time.
# Word 670 ("intub") appears 1 time.
# Word 671 ("involv") appears 1 time.
# Word 675 ("lobe") appears 5 time.
# Word 689 ("penicillin") appears 1 time.
# Word 694 ("prophylaxi") appears 3 time.
# Word 696 ("rash") appears 1 time.
# Word 701 ("sputum") appears 1 time.
# Word 704 ("tissu") appears 1 time.
# Word 705 ("treat") appears 2 time.
# Word 709 ("withdraw") appears 1 time.
# Word 710 ("afebril") appears 2 time.
# Word 727 ("die") appears 2 time.
# Word 730 ("drainag") appears 1 time.
# Word 742 ("identifi") appears 1 time.
# Word 750 ("lisinopril") appears 3 time.
# Word 752 ("make") appears 1 time.
# Word 781 ("subcutan") appears 2 time.
# Word 790 ("urin") appears 1 time.
# Word 792 ("visual") appears 1 time.
# Word 803 ("albuterol") appears 1 time.
# Word 818 ("contact") appears 1 time.
# Word 838 ("even") appears 1 time.
# Word 852 ("inhal") appears 3 time.
# Word 859 ("minor") appears 1 time.
# Word 861 ("morn") appears 1 time.
# Word 875 ("promin") appears 1 time.
# Word 876 ("puff") appears 1 time.
# Word 882 ("send") appears 1 time.
# Word 886 ("sleep") appears 1 time.
# Word 887 ("slight") appears 2 time.
# Word 908 ("base") appears 1 time.
# Word 916 ("caus") appears 2 time.
# Word 919 ("code") appears 1 time.
# Word 923 ("consid") appears 2 time.
# Word 929 ("diarrhea") appears 1 time.
# Word 940 ("health") appears 1 time.
# Word 941 ("hold") appears 1 time.
# Word 952 ("lactat") appears 1 time.
# Word 970 ("pressor") appears 1 time.
# Word 971 ("probabl") appears 3 time.
# Word 975 ("quick") appears 1 time.
# Word 977 ("replet") appears 1 time.
# Word 979 ("resolv") appears 2 time.
# Word 985 ("sick") appears 1 time.
# Word 989 ("suggest") appears 1 time.
# Word 1007 ("avoid") appears 3 time.
# Word 1011 ("better") appears 1 time.
# Word 1026 ("deep") appears 2 time.
# Word 1029 ("discuss") appears 1 time.
# Word 1032 ("electrolyt") appears 1 time.
# Word 1039 ("expect") appears 1 time.
# Word 1051 ("frequent") appears 1 time.
# Word 1062 ("intervent") appears 3 time.
# Word 1064 ("issu") appears 10 time.
# Word 1081 ("rang") appears 1 time.
# Word 1086 ("senna") appears 2 time.
# Word 1100 ("thrombosi") appears 2 time.
# Word 1112 ("workup") appears 1 time.
# Word 1136 ("synephrin") appears 1 time.
# Word 1148 ("benign") appears 1 time.
# Word 1156 ("desir") appears 1 time.
# Word 1172 ("malign") appears 1 time.
# Word 1177 ("nodul") appears 1 time.
# Word 1181 ("patholog") appears 1 time.
# Word 1206 ("crackl") appears 1 time.
# Word 1208 ("despit") appears 2 time.
# Word 1220 ("opac") appears 3 time.
# Word 1224 ("pneumonia") appears 4 time.
# Word 1225 ("presum") appears 3 time.
# Word 1228 ("resuscit") appears 1 time.
# Word 1232 ("usual") appears 2 time.
# Word 1277 ("relat") appears 1 time.
# Word 1280 ("sertralin") appears 2 time.
# Word 1288 ("thorac") appears 5 time.
# Word 1300 ("associ") appears 3 time.
# Word 1311 ("communiti") appears 3 time.
# Word 1316 ("current") appears 2 time.
# Word 1331 ("final") appears 1 time.
# Word 1342 ("inject") appears 1 time.
# Word 1359 ("product") appears 1 time.
# Word 1392 ("zoloft") appears 1 time.
# Word 1407 ("long") appears 3 time.
# Word 1413 ("review") appears 2 time.
# Word 1414 ("side") appears 2 time.
# Word 1440 ("ipratropium") appears 1 time.
# Word 1451 ("proceed") appears 1 time.
# Word 1459 ("abl") appears 1 time.
# Word 1462 ("acquir") appears 3 time.
# Word 1469 ("bacteria") appears 1 time.
# Word 1474 ("consolid") appears 1 time.
# Word 1478 ("dementia") appears 4 time.
# Word 1499 ("nutrit") appears 1 time.
# Word 1504 ("osteoporosi") appears 1 time.
# Word 1509 ("rapid") appears 1 time.
# Word 1512 ("reflect") appears 1 time.
# Word 1526 ("specimen") appears 2 time.
# Word 1575 ("liter") appears 1 time.
# Word 1576 ("mask") appears 1 time.
# Word 1579 ("mucous") appears 1 time.
# Word 1592 ("reintub") appears 1 time.
# Word 1596 ("sentenc") appears 1 time.
# Word 1598 ("speak") appears 1 time.
# Word 1610 ("weak") appears 1 time.
# Word 1633 ("glass") appears 1 time.
# Word 1635 ("grind") appears 1 time.
# Word 1691 ("comparison") appears 1 time.
# Word 1749 ("longer") appears 1 time.
# Word 1789 ("pneumothorax") appears 1 time.
# Word 1801 ("broad") appears 2 time.
# Word 1816 ("nasal") appears 1 time.
# Word 1824 ("spectrum") appears 1 time.
# Word 1832 ("accid") appears 1 time.
# Word 1933 ("oropharynx") appears 1 time.
# Word 1966 ("membran") appears 1 time.
# Word 1973 ("normocephal") appears 1 time.
# Word 2010 ("zestril") appears 1 time.
# Word 2018 ("locul") appears 4 time.
# Word 2048 ("combiv") appears 1 time.
# Word 2060 ("sore") appears 2 time.
# Word 2076 ("talk") appears 1 time.
# Word 2082 ("cardiomegali") appears 1 time.
# Word 2122 ("wide") appears 1 time.
# Word 2125 ("dental") appears 1 time.
# Word 2136 ("cannula") appears 1 time.
# Word 2157 ("video") appears 5 time.
# Word 2170 ("palpat") appears 1 time.
# Word 2172 ("rare") appears 1 time.
# Word 2173 ("reaction") appears 1 time.
# Word 2183 ("cerebrovascular") appears 1 time.
# Word 2197 ("nicotin") appears 2 time.
# Word 2198 ("patch") appears 2 time.
# Word 2213 ("fahrenheit") appears 2 time.
# Word 2226 ("parkinson") appears 4 time.
# Word 2300 ("desatur") appears 1 time.
# Word 2325 ("specif") appears 1 time.
# Word 2409 ("wish") appears 1 time.
# Word 2450 ("atraumat") appears 1 time.
# Word 2454 ("bodi") appears 4 time.
# Word 2455 ("ceftazidim") appears 3 time.
# Word 2456 ("cytolog") appears 2 time.
# Word 2457 ("eosinophil") appears 1 time.
# Word 2458 ("graviti") appears 1 time.
# Word 2459 ("hemoptysi") appears 1 time.
# Word 2460 ("nonrebreath") appears 1 time.
# Word 2461 ("pariet") appears 1 time.
# Word 2462 ("pulmonolog") appears 1 time.
# Word 2463 ("pursu") appears 1 time.
# Word 2464 ("rhinorrhea") appears 1 time.
# Word 2465 ("rod") appears 1 time.
# Word 2466 ("stasi") appears 1 time.
# Word 2467 ("transderm") appears 1 time.
# Word 2468 ("trazodon") appears 1 time.

# %%
# TF-IDF
corpus_tfidf = tfidf[bow_corpus]

# %%
from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.07868455196498843),
#  (1, 0.04670363015139512),
#  (2, 0.049809526865249004),
#  (3, 0.08589417644905668),
#  (4, 0.010786961320840201),
#  (5, 0.020827843349254818),
#  (6, 0.07917393765878254),
#  (7, 0.0227117686491569),
#  (8, 0.026542750528308793),
#  (9, 0.02882932686821098),
#  (10, 0.016595072945082518),
#  (11, 0.00957024324743943),
#  (12, 0.13092457685631823),
#  (13, 0.0544723058259119),
#  (14, 0.04606813778078839),
#  (15, 0.023697827803126917),
#  (16, 0.11596470991522938),
#  (17, 0.02588141725393758),
#  (18, 0.04543219461625163),
#  (19, 0.019577542825540598),
#  (20, 0.02393842765167954),
#  (21, 0.04141083235529787),
#  (22, 0.024538306914657918),
#  (23, 0.06987584591801738),
#  (24, 0.025582380806360116),
#  (25, 0.10672119073433999),
#  (26, 0.03133163979141356),
#  (27, 0.028009120501188083),
#  (28, 0.03495542790494231),
#  (29, 0.01445443958985727),
#  (30, 0.03464952133129495),
#  (31, 0.026140851597319284),
#  (32, 0.040737881764606555),
#  (33, 0.062231806416226346),
#  (34, 0.015515432234677913),
#  (35, 0.021726572010166586),
#  (36, 0.04008692697002637),
#  (37, 0.02538145911330247),
# Topic: 5 Word: 0.002*"postop" + 0.002*"valv" + 0.002*"tube" + 0.002*"aortic" + 0.002*"stent" + 0.002*"ventricular" + 0.001*"capsul" + 0.001*"disp" + 0.001*"refil" + 0.001*"regurgit"
# Topic: 6 Word: 0.003*"graft" + 0.003*"postop" + 0.003*"dialysi" + 0.003*"hemodialysi" + 0.002*"catheter" + 0.002*"descend" + 0.002*"coronari" + 0.002*"prefix" + 0.002*"aortic" + 0.002*"mouth"
# Topic: 7 Word: 0.002*"postop" + 0.002*"aortic" + 0.002*"hematocrit" + 0.002*"pancreat" + 0.002*"iliac" + 0.001*"valv" + 0.001*"disp" + 0.001*"refil" + 0.001*"oper" + 0.001*"incis"
# Topic: 8 Word: 0.003*"fractur" + 0.002*"postop" + 0.002*"graft" + 0.002*"seizur" + 0.002*"spine" + 0.002*"disp" + 0.002*"capsul" + 0.002*"refil" + 0.001*"hematoma" + 0.001*"kidney"
# Topic: 9 Word: 0.003*"disp" + 0.003*"refil" + 0.002*"capsul" + 0.002*"aortic" + 0.002*"postop" + 0.002*"stent" + 0.002*"releas" + 0.002*"valv" + 0.002*"ercp" + 0.002*"bleed"

# %%
# Classification of the topics
# Performance evaluation by classifying sample document using LDA Bag of Words model

# %%
processed_docs[64]
# Out:
# ['admiss',
#  'date',
#  'discharg',
#  'date',
#  'date',
#  'birth',
#  'servic',
#  'medicin',
#  'allergi',
#  'know',
#  'allergi',
#  'advers',
#  'drug',
#  'reaction',
#  'attend',
#  'doctor',
#  'chief',
#  'complaint',
#  'blurri',
#  'vision',
#  'major',
#  'surgic',
#  'invas',
#  'procedur',
#  'histori',
#  'present',
#  'ill',
#  'year',
#  'male',
#  'histori',
#  'hypertens',
#  'beta',
#  'blockad',
#  'lasix',
#  'hydralazin',
#  'imdur',
#  'metolazon',
#  'complic',
#  'chronic',
#  'kidney',
#  'diseas',
#  'stage',
#  'obes',
#  'tobacco',
#  'abus',
#  'present',
#  'today',
#  'emerg',
#  'room',
#  'hospit',
#  'clinic',
#  'note',
#  'sever',
#  'bilater',
#  'papilledema',
#  'opthomolog',
#  'suggest',
#  'secondari',
#  'elev',
#  'intracrani',
#  'pressur',
#  'set',
#  'malign',
#  'hypertens',
#  'pseudotumor',
#  'cerebri',
#  'symptomat',
#  'blurri',
#  'vision',
#  'past',
#  'month',
#  'absenc',
#  'headach',
#  'central',
#  'symptom',
#  'note',
#  'gait',
#  'instabl',
#  'blood',
#  'pressur',
#  'note',
#  'take',
#  'usual',
#  'dose',
#  'blood',
#  'pressur',
#  'med',
#  'unknown',
#  'improv',
#  'systol',
#  'transfer',
#  'micu',
#  'manag',
#  'hypertens',
#  'emerg',
#  'past',
#  'medic',
#  'histori',
#  'hypertens',
#  'hypertens',
#  'chronic',
#  'kidney',
#  'diseas',
#  'stage',
#  'systol',
#  'heart',
#  'failur',
#  'eject',
#  'fraction',
#  'hospit',
#  'obes',
#  'tobacco',
#  'abus',
#  'social',
#  'histori',
#  'patient',
#  'continu',
#  'smoke',
#  'cigarett',
#  'recent',
#  'smoke',
#  'quit',
#  'time',
#  'famili',
#  'histori',
#  'histori',
#  'hypertens',
#  'heart',
#  'diseas',
#  'cancer',
#  'physic',
#  'exam',
#  'admiss',
#  'exam',
#  'obes',
#  'heent',
#  'dilat',
#  'fundoscop',
#  'exam',
#  'reveal',
#  'bilater',
#  'papilledema',
#  'evid',
#  'flame',
#  'hemorrhag',
#  'distinct',
#  'cotton',
#  'whool',
#  'spot',
#  'mucous',
#  'accumul',
#  'canthal',
#  'fold',
#  'mild',
#  'proptosi',
#  'apprecait',
#  'cervic',
#  'apprecati',
#  'perrla',
#  'faint',
#  'heart',
#  'sound',
#  'pansystol',
#  'murmur',
#  'best',
#  'apprecait',
#  'mitral',
#  'region',
#  'carotid',
#  'bruit',
#  'apprecait',
#  'rub',
#  'gallop',
#  'lung',
#  'ctabl',
#  'lung',
#  'field',
#  'obes',
#  'nontend',
#  'appreci',
#  'organomegali',
#  'appreci',
#  'edema',
#  'neuro',
#  'focal',
#  'neurolog',
#  'deficit',
#  'appeci',
#  'focus',
#  'cranial',
#  'nerv',
#  'exam',
#  'brief',
#  'gross',
#  'motor',
#  'exam',
#  'discharg',
#  'exam',
#  'sat',
#  'general',
#  'appear',
#  'morbid',
#  'obes',
#  'comfort',
#  'appropri',
#  'heent',
#  'perrla',
#  'eomi',
#  'sclera',
#  'anicter',
#  'clear',
#  'neck',
#  'suppl',
#  'thyromegali',
#  'see',
#  'carotid',
#  'bruit',
#  'lung',
#  'bilat',
#  'heart',
#  'displac',
#  'abdomen',
#  'nab',
#  'soft',
#  'mass',
#  'rebound',
#  'guard',
#  'extrem',
#  'peripher',
#  'puls',
#  'radial',
#  'skin',
#  'rash',
#  'lesion',
#  'lymph',
#  'cervic',
#  'axillari',
#  'inguin',
#  'neuro',
#  'awak',
#  'grossli',
#  'intact',
#  'muscl',
#  'strength',
#  'sensat',
#  'grossli',
#  'intact',
#  'dtrs',
#  'symmetr',
#  'cerebellar',
#  'exam',
#  'intact',
#  'steadi',
#  'gait',
#  'pertin',
#  'result',
#  'admiss',
#  'lab',
#  'blood',
#  'mchc',
#  'blood',
#  'neut',
#  'lymph',
#  'mono',
#  'baso',
#  'blood',
#  'blood',
#  'glucos',
#  'urean',
#  'creat',
#  'angap',
#  'blood',
#  'calcium',
#  'phos',
#  'dischcarg',
#  'lab',
#  'blood',
#  'mchc',
#  'blood',
#  'glucos',
#  'urean',
#  'creat',
#  'angap',
#  'blood',
#  'calcium',
#  'phos',
#  'blood',
#  'aldosteron',
#  'blood',
#  'renin',
#  'lab',
#  'blood',
#  'alkpho',
#  'totbili',
#  'blood',
#  'imag',
#  'head',
#  'contrast',
#  'acut',
#  'intracrani',
#  'patholog',
#  'bilater',
#  'proptosi',
#  'renal',
#  'kidney',
#  'increas',
#  'echogen',
#  'consist',
#  'chronic',
#  'kidney',
#  'diseas',
#  'simpl',
#  'cyst',
#  'right',
#  'kidney',
#  'upper',
#  'pole',
#  'lower',
#  'pole',
#  'doppler',
#  'evalu',
#  'renal',
#  'arteri',
#  'arcuat',
#  'segment',
#  'vessel',
#  'renal',
#  'parenchyma',
#  'normal',
#  'limit',
#  'ultrasound',
#  'doppler',
#  'evid',
#  'renal',
#  'arteri',
#  'stenosi',
#  'leav',
#  'atrium',
#  'mild',
#  'dilat',
#  'right',
#  'atrium',
#  'moder',
#  'dilat',
#  'estim',
#  'right',
#  'atrial',
#  'pressur',
#  'mmhg',
#  'sever',
#  'symmetr',
#  'leav',
#  'ventricular',
#  'hypertrophi',
#  'leav',
#  'ventricular',
#  'caviti',
#  'size',
#  'normal',
#  'overal',
#  'leav',
#  'ventricular',
#  'systol',
#  'function',
#  'normal',
#  'lvef',
#  'tissu',
#  'doppler',
#  'imag',
#  'suggest',
#  'increas',
#  'leav',
#  'ventricular',
#  'fill',
#  'pressur',
#  'pcwp',
#  'mmhg',
#  'right',
#  'ventricular',
#  'free',
#  'wall',
#  'hypertrophi',
#  'right',
#  'ventricular',
#  'chamber',
#  'size',
#  'normal',
#  'depress',
#  'free',
#  'wall',
#  'contractil',
#  'ascend',
#  'aorta',
#  'mild',
#  'dilat',
#  'aortic',
#  'arch',
#  'mild',
#  'dilat',
#  'aortic',
#  'valv',
#  'leaflet',
#  'appear',
#  'structur',
#  'normal',
#  'good',
#  'leaflet',
#  'excurs',
#  'aortic',
#  'stenosi',
#  'aortic',
#  'regurgit',
#  'mitral',
#  'valv',
#  'appear',
#  'structur',
#  'normal',
#  'trivial',
#  'mitral',
#  'regurgit',
#  'pulmonari',
#  'arteri',
#  'systol',
#  'pressur',
#  'determin',
#  'pericardi',
#  'effus',
#  'brief',
#  'hospit',
#  'cours',
#  'hypertens',
#  'emerg',
#  'present',
#  'systol',
#  'blurri',
#  'vision',
#  'papilledema',
#  'patient',
#  'blood',
#  'pressur',
#  'mark',
#  'elev',
#  'systol',
#  'blood',
#  'pressur',
#  'rang',
#  'stay',
#  'review',
#  'prior',
#  'note',
#  'outlin',
#  'longstand',
#  'histori',
#  'poor',
#  'control',
#  'blood',
#  'pressur',
#  'home',
#  'isosorbid',
#  'carvedilol',
#  'discontinu',
#  'labetalol',
#  'uptitr',
#  'hydral',
#  'downtitr',
#  'clonidin',
#  'week',
#  'patch',
#  'start',
#  'furosemid',
#  'metolazon',
#  'continu',
#  'goal',
#  'leav',
#  'normal',
#  'limit',
#  'felt',
#  'patient',
#  'need',
#  'workup',
#  'secondari',
#  'caus',
#  'hypertens',
#  'meantim',
#  'renal',
#  'arteri',
#  'ultrasound',
#  'show',
#  'renal',
#  'arteri',
#  'stenosi',
#  'chornic',
#  'bilater',
#  'chang',
#  'consist',
#  'ckdd',
#  'like',
#  'workup',
#  'hypokalemia',
#  'workup',
#  'includ',
#  'urin',
#  'metanephrin',
#  'dexamethason',
#  'suppress',
#  'test',
#  'young',
#  'degre',
#  'hypertens',
#  'compliant',
#  'medic',
#  'initi',
#  'start',
#  'spironolacton',
#  'give',
#  'report',
#  'think',
#  'help',
#  'hypokalemia',
#  'day',
#  'dose',
#  'discontinu',
#  'ideal',
#  'renin',
#  'aldosteron',
#  'level',
#  'draw',
#  'prior',
#  'discharg',
#  'pend',
#  'day',
#  'discontinu',
#  'recommend',
#  'restart',
#  'medic',
#  'appropri',
#  'studi',
#  'like',
#  'patient',
#  'sleep',
#  'apnea',
#  'note',
#  'desat',
#  'sleep',
#  'loud',
#  'snore',
#  'desat',
#  'resolv',
#  'instant',
#  'wake',
#  'smoke',
#  'obes',
#  'like',
#  'worsen',
#  'hypertens',
#  'recommend',
#  'outpati',
#  'sleep',
#  'studi',
#  'hypokalemia',
#  'note',
#  'hypokalem',
#  'potassium',
#  'concern',
#  'state',
#  'give',
#  'concommitt',
#  'resist',
#  'hypertens',
#  'requir',
#  'potassium',
#  'replet',
#  'hospit',
#  'unit',
#  'remain',
#  'outpati',
#  'record',
#  'demonstr',
#  'histori',
#  'potassium',
#  'start',
#  'spironolacton',
#  'dose',
#  'appear',
#  'help',
#  'potassium',
#  'retent',
#  'unusu',
#  'set',
#  'elev',
#  'creatinin',
#  'chronic',
#  'renal',
#  'failur',
#  'emphas',
#  'concern',
#  'state',
#  'spironolacton',
#  'temporarili',
#  'renin',
#  'male',
#  'level',
#  'draw',
#  'intracrani',
#  'hypertens',
#  'like',
#  'secondari',
#  'systmem',
#  'hypertens',
#  'neurolog',
#  'evalaut',
#  'patient',
#  'suggest',
#  'potenti',
#  'control',
#  'assess',
#  'pseudotumor',
#  'cerebrii',
#  'defer',
#  'outpati',
#  'set',
#  'papilledema',
#  'improv',
#  'improv',
#  'control',
#  'chronic',
#  'kidney',
#  'diseas',
#  'patient',
#  'creatinin',
#  'elev',
#  'baselin',
#  'like',
#  'secondari',
#  'hypertens',
#  'nephropathi',
#  'continu',
#  'sevalam',
#  'nephrocap',
#  'chronic',
#  'systol',
#  'echo',
#  'record',
#  'note',
#  'state',
#  'show',
#  'increas',
#  'wall',
#  'thick',
#  'estim',
#  'lvef',
#  'global',
#  'hypokinesi',
#  'focal',
#  'wall',
#  'motion',
#  'abnorm',
#  'increas',
#  'prefix',
#  'prefix',
#  'prefix',
#  'estim',
#  'systol',
#  'pressur',
#  'patient',
#  'appear',
#  'euvolem',
#  'exam',
#  'evid',
#  'acut',
#  'schf',
#  'exacerb',
#  'blood',
#  'pressur',
#  'control',
#  'adjust',
#  'includ',
#  'addit',
#  'spironolacton',
#  'regimen',
#  'despit',
#  'renal',
#  'impair',
#  'benefit',
#  'addit',
#  'acei',
#  'discuss',
#  'namei',
#  'nephrologist',
#  'continu',
#  'beta',
#  'blocker',
#  'switch',
#  'metoprolol',
#  'carvedilol',
#  'labetalol',
#  'lasix',
#  'metolazon',
#  'show',
#  'transit',
#  'issu',
#  'namei',
#  'nephrolog',
#  'follow',
#  'schedul',
#  'need',
#  'outpati',
#  'sleep',
#  'studi',
#  'benefit',
#  'work',
#  'secondari',
#  'hypertens',
#  'facil',
#  'follow',
#  'renin',
#  'male',
#  'ratio',
#  'draw',
#  'urin',
#  'metaneprhin',
#  'suppress',
#  'test',
#  'patient',
#  'code',
#  'admiss',
#  'benefit',
#  'nutrit',
#  'consult',
#  'order',
#  'outpt',
#  'thursday',
#  'need',
#  'medic',
#  'admiss',
#  'complex',
#  'vitamin',
#  'folic',
#  'acid',
#  'nephrocap',
#  'prescrib',
#  'provid',
#  'dosag',
#  'uncertain',
#  'carvedilol',
#  'tablet',
#  'tablet',
#  'mouth',
#  'twice',
#  'furosemid',
#  'tablet',
#  'tablet',
#  'mouth',
#  'twice',
#  'hydralazin',
#  'tablet',
#  'tablet',
#  'mouth',
#  'time',
#  'isosorbid',
#  'mononitr',
#  'tablet',
#  'extend',
#  'releas',
#  'tablet',
#  'mouth',
#  'qday',
#  'metolazon',
#  'tablet',
#  'tablet',
#  'mouth',
#  'qday',
#  'metoprolol',
#  'tartrat',
#  'tablet',
#  'tablet',
#  'mouth',
#  'twice',
#  'potassium',
#  'chlorid',
#  'tablet',
#  'particl',
#  'crystal',
#  'tablet',
#  'mouth',
#  'sevelam',
#  'prescrib',
#  'provid',
#  'dosag',
#  'uncertain',
#  'discharg',
#  'medic',
#  'furosemid',
#  'tablet',
#  'tablet',
#  'time',
#  'hydralazin',
#  'tablet',
#  'tablet',
#  'time',
#  'disp',
#  'tablet',
#  'refil',
#  'metolazon',
#  'tablet',
#  'tablet',
#  'daili',
#  'daili',
#  'sevelam',
#  'carbon',
#  'tablet',
#  'tablet',
#  'meal',
#  'time',
#  'meal',
#  'labetalol',
#  'tablet',
#  'tablet',
#  'time',
#  'disp',
#  'tablet',
#  'refil',
#  'clonidin',
#  'patch',
#  'week',
#  'patch',
#  'transderm',
#  'qsat',
#  'saturday',
#  'disp',
#  'patch',
#  'week',
#  'refil',
#  'nephrocap',
#  'capsul',
#  'capsul',
#  'potassium',
#  'chlorid',
#  'tablet',
#  'particl',
#  'crystal',
#  'tablet',
#  'particl',
#  'crystal',
#  'disp',
#  'tablet',
#  'particl',
#  'crystal',
#  'refil',
#  'lisinopril',
#  'tablet',
#  'tablet',
#  'disp',
#  'tablet',
#  'refil',
#  'discharg',
#  'disposit',
#  'home',
#  'discharg',
#  'diagnosi',
#  'primari',
#  'diagnosi',
#  'hypertens',
#  'emerg',
#  'secondari',
#  'diagnos',
#  'chronic',
#  'kidney',
#  'diseas',
#  'chronic',
#  'systol',
#  'heart',
#  'failur',
#  'tobacco',
#  'abus',
#  'obes',
#  'discharg',
#  'condit',
#  'mental',
#  'status',
#  'clear',
#  'coher',
#  'level',
#  'conscious',
#  'alert',
#  'interact',
#  'activ',
#  'status',
#  'ambulatori',
#  'independ',
#  'discharg',
#  'instruct',
#  'dear',
#  'know',
#  'lastnam',
#  'admit',
#  'intens',
#  'care',
#  'unit',
#  'hospit',
#  'high',
#  'blood',
#  'pressur',
#  'blurri',
#  'vision',
#  'blurri',
#  'vision',
#  'like',
#  'caus',
#  'high',
#  'blood',
#  'pressur',
#  'blood',
#  'pressur',
#  'high',
#  'risk',
#  'complic',
#  'includ',
#  'kidney',
#  'damag',
#  'possibl',
#  'stroke',
#  'monitor',
#  'close',
#  'chang',
#  'blood',
#  'pressur',
#  'medic',
#  'help',
#  'better',
#  'control',
#  'blood',
#  'pressur',
#  'follow',
#  'chang',
#  'medic',
#  'stop',
#  'carvedilol',
#  'metoprolol',
#  'isosorbid',
#  'mononitr',
#  'decreas',
#  'hydralazin',
#  'time',
#  'time',
#  'increas',
#  'potassium',
#  'chlorid',
#  'chrystal',
#  'increas',
#  'dose',
#  'dose',
#  'start',
#  'clonidin',
#  'patch',
#  'week',
#  'labetalol',
#  'time',
#  'lisinopril',
#  'chang',
#  'medic',
#  'continu',
#  'import',
#  'blood',
#  'pressur',
#  'medic',
#  'monitor',
#  'blood',
#  'pressur',
#  'blood',
#  'pressur',
#  'persist',
#  'higher',
#  'contact',
#  'doctor',
#  'develop',
#  'worsen',
#  'blurri',
#  'vision',
#  'headach',
#  'chest',
#  'pain',
#  'short',
#  'breath',
#  'slur',
#  'speech',
#  'weak',
#  'face',
#  'bodi',
#  'seek',
#  'medic',
#  'attent',
#  'immedi',
#  'concern',
#  'condit',
#  'call',
#  'obstruct',
#  'sleep',
#  'apnea',
#  'recommend',
#  ...]

# %%
for index, score in sorted(lda_model[bow_corpus[64]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.7687466740608215
# Topic: 0.009*"postop" + 0.009*"coronari" + 0.006*"examin" + 0.005*"hematocrit" + 0.005*"reveal" + 0.005*"surgeri" + 0.005*"rhythm" + 0.005*"graft" + 0.005*"room" + 0.004*"count"
#
# Score: 0.098329097032547
# Topic: 0.007*"releas" + 0.006*"capsul" + 0.005*"effus" + 0.005*"refil" + 0.005*"disp" + 0.004*"locat" + 0.004*"renal" + 0.003*"angap" + 0.003*"aortic" + 0.003*"delay"
#
# Score: 0.07759689539670944
# Topic: 0.006*"renal" + 0.005*"bleed" + 0.005*"abdomin" + 0.004*"failur" + 0.004*"hematocrit" + 0.003*"cell" + 0.003*"examin" + 0.003*"treat" + 0.003*"diabet" + 0.003*"elev"
#
# Score: 0.04212407022714615
# Topic: 0.005*"seizur" + 0.004*"head" + 0.004*"urin" + 0.004*"pneumonia" + 0.004*"locat" + 0.003*"mental" + 0.003*"fractur" + 0.003*"month" + 0.003*"tube" + 0.003*"small"
#
# Score: 0.012401793152093887
# Topic: 0.005*"effus" + 0.005*"cultur" + 0.004*"ventricular" + 0.004*"capsul" + 0.004*"bleed" + 0.004*"atrial" + 0.004*"releas" + 0.003*"pneumonia" + 0.003*"upper" + 0.003*"refil"

# %%
# Performance evaluation by classifying sample document using LDA TF-IDF model

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[64]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.9216979742050171
# Topic: 0.002*"mouth" + 0.002*"fractur" + 0.002*"aspir" + 0.002*"tube" + 0.002*"renal" + 0.002*"expir" + 0.002*"capsul" + 0.002*"intub" + 0.002*"seizur" + 0.002*"pneumonia"
#
# Score: 0.07701976597309113
# Topic: 0.003*"postop" + 0.003*"bleed" + 0.002*"oper" + 0.002*"mouth" + 0.002*"hematocrit" + 0.002*"percent" + 0.002*"coronari" + 0.002*"valv" + 0.002*"seizur" + 0.002*"vein"
